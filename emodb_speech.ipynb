# %%
import numpy as np # linear algebra
import pandas as pd 
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import Audio
import tensorflow as tf

# %%
Emotion = {'T':  'Sad', 'W':'Angry','E' :  'Disgust', 'A' : 'Fear', 'F' : 'Happy', 'N': 'Neutral','L':'Boredom'}

# %%
data = {'filename':[],
        'label':[]}
Data = pd.DataFrame(data)
Data
# Out:
# Empty DataFrame
# Columns: [filename, label]
# Index: []

# %%
directory = 'wav'
for filename in os.listdir(directory):
    emotion = filename[5]
    f = os.path.join(directory, filename)
    Data.loc[len(Data.index)] = [f, Emotion[emotion]] 
Data
# Out:
#             filename    label
# 0    wav/16a02Lb.wav  Boredom
# 1    wav/14a07Wc.wav    Angry
# 2    wav/10a07Ad.wav     Fear
# 3    wav/13a05Ea.wav  Disgust
# 4    wav/14a05Wa.wav    Angry
# ..               ...      ...
# 530  wav/08b01Fd.wav    Happy
# 531  wav/03b02Aa.wav     Fear
# 532  wav/09a05Lc.wav  Boredom
# 533  wav/08a05Lc.wav  Boredom
# 534  wav/14a05Aa.wav     Fear
#
# [535 rows x 2 columns]

# %%
pip install opensmile
# Out:
# Requirement already satisfied: opensmile in /opt/homebrew/lib/python3.11/site-packages (2.5.0)
# Requirement already satisfied: audobject>=0.6.1 in /opt/homebrew/lib/python3.11/site-packages (from opensmile) (0.7.11)
# Requirement already satisfied: audinterface>=0.7.0 in /opt/homebrew/lib/python3.11/site-packages (from opensmile) (1.2.1)
# Requirement already satisfied: audeer>=1.18.0 in /opt/homebrew/lib/python3.11/site-packages (from audinterface>=0.7.0->opensmile) (2.0.0)
# Requirement already satisfied: audformat<2.0.0,>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from audinterface>=0.7.0->opensmile) (1.1.2)
# Requirement already satisfied: audiofile>=1.3.0 in /opt/homebrew/lib/python3.11/site-packages (from audinterface>=0.7.0->opensmile) (1.4.0)
# Requirement already satisfied: audmath>=1.3.0 in /opt/homebrew/lib/python3.11/site-packages (from audinterface>=0.7.0->opensmile) (1.4.0)
# Requirement already satisfied: audresample<2.0.0,>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from audinterface>=0.7.0->opensmile) (1.3.3)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/homebrew/lib/python3.11/site-packages (from audobject>=0.6.1->opensmile) (7.1.0)
# Requirement already satisfied: oyaml in /opt/homebrew/lib/python3.11/site-packages (from audobject>=0.6.1->opensmile) (1.0)
# Requirement already satisfied: packaging in /Users/denz/Library/Python/3.11/lib/python/site-packages (from audobject>=0.6.1->opensmile) (23.2)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from audeer>=1.18.0->audinterface>=0.7.0->opensmile) (4.66.2)
# Requirement already satisfied: iso-639 in /opt/homebrew/lib/python3.11/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (0.4.5)
# Requirement already satisfied: iso3166 in /opt/homebrew/lib/python3.11/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.1.1)
# Requirement already satisfied: pyyaml>=5.4.1 in /opt/homebrew/lib/python3.11/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (6.0.1)
# Requirement already satisfied: pandas>=1.4.1 in /opt/homebrew/lib/python3.11/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.2.1)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.26.4)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/homebrew/lib/python3.11/site-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (0.12.1)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from importlib-metadata>=4.8.0->audobject>=0.6.1->opensmile) (3.18.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/denz/Library/Python/3.11/lib/python/site-packages (from pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2024.1)
# Requirement already satisfied: cffi>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from soundfile>=0.12.1->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.16.0)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2.22)
# Requirement already satisfied: six>=1.5 in /Users/denz/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import opensmile

smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.Functionals,
)
y = smile.process_file('wav/03a01Fa.wav')
y
# Out:
#                                                audspec_lengthL1norm_sma_range  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                        2.935072
#
#                                                audspec_lengthL1norm_sma_maxPos  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                         0.203297
#
#                                                audspec_lengthL1norm_sma_minPos  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                         0.010989
#
#                                                audspec_lengthL1norm_sma_quartile1  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                            0.295957
#
#                                                audspec_lengthL1norm_sma_quartile2  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                            0.521095
#
#                                                audspec_lengthL1norm_sma_quartile3  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                             1.02788
#
#                                                audspec_lengthL1norm_sma_iqr1-2  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                         0.225138
#
#                                                audspec_lengthL1norm_sma_iqr2-3  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                         0.506785
#
#                                                audspec_lengthL1norm_sma_iqr1-3  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                         0.731923
#
#                                                audspec_lengthL1norm_sma_percentile1.0  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                                0.036379
#
#                                                ...  \
# file            start  end                     ...
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250  ...
#
#                                                mfcc_sma_de[14]_peakRangeAbs  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                      4.534245
#
#                                                mfcc_sma_de[14]_peakRangeRel  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                      0.369439
#
#                                                mfcc_sma_de[14]_peakMeanAbs  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                     2.608829
#
#                                                mfcc_sma_de[14]_peakMeanMeanDist  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                          2.575876
#
#                                                mfcc_sma_de[14]_peakMeanRel  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                    19.005924
#
#                                                mfcc_sma_de[14]_minRangeRel  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                     0.681891
#
#                                                mfcc_sma_de[14]_meanRisingSlope  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                       117.093933
#
#                                                mfcc_sma_de[14]_stddevRisingSlope  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                          56.662125
#
#                                                mfcc_sma_de[14]_meanFallingSlope  \
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                        120.517212
#
#                                                mfcc_sma_de[14]_stddevFallingSlope
# file            start  end
# wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                           53.837585
#
# [1 rows x 6373 columns]

# %%
features_df = pd.DataFrame()
features_df
directory = 'wav'
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    features = smile.process_file(f)
    features.loc[f, 'filename'] = f
    features_df = pd.concat([features_df, features])
    # Data.loc[len(Data.index)] = [f, Emotion[emotion]] 

features_df.reset_index(drop=True, inplace=True)
features_df
# Out:
#      audspec_lengthL1norm_sma_range  audspec_lengthL1norm_sma_maxPos  \
# 0                          3.552382                         0.313433
# 1                          3.742779                         0.793970
# 2                          2.909269                         0.352941
# 3                          2.482837                         0.082524
# 4                          3.798883                         0.572519
# ..                              ...                              ...
# 530                        3.362022                         0.224066
# 531                        3.407733                         0.455150
# 532                        3.657910                         0.124620
# 533                        2.882161                         0.126521
# 534                        2.880234                         0.585657
#
#      audspec_lengthL1norm_sma_minPos  audspec_lengthL1norm_sma_quartile1  \
# 0                           0.019900                            0.416416
# 1                           0.000000                            0.310724
# 2                           0.973856                            0.571077
# 3                           0.961165                            0.665067
# 4                           0.020356                            0.357622
# ..                               ...                                 ...
# 530                         0.970954                            0.534979
# 531                         0.000000                            0.775938
# 532                         0.009119                            0.492631
# 533                         0.961071                            0.443412
# 534                         0.011952                            0.560481
#
#      audspec_lengthL1norm_sma_quartile2  audspec_lengthL1norm_sma_quartile3  \
# 0                              0.864809                            1.466342
# 1                              0.652575                            1.473212
# 2                              1.109974                            1.521203
# 3                              1.097788                            1.647235
# 4                              0.830027                            1.643402
# ..                                  ...                                 ...
# 530                            1.055917                            1.671821
# 531                            1.113877                            1.599168
# 532                            0.691403                            0.924337
# 533                            0.725012                            1.138016
# 534                            0.923816                            1.256618
#
#      audspec_lengthL1norm_sma_iqr1-2  audspec_lengthL1norm_sma_iqr2-3  \
# 0                           0.448394                         0.601533
# 1                           0.341851                         0.820637
# 2                           0.538897                         0.411230
# 3                           0.432721                         0.549446
# 4                           0.472405                         0.813375
# ..                               ...                              ...
# 530                         0.520938                         0.615904
# 531                         0.337938                         0.485291
# 532                         0.198772                         0.232935
# 533                         0.281601                         0.413004
# 534                         0.363336                         0.332802
#
#      audspec_lengthL1norm_sma_iqr1-3  audspec_lengthL1norm_sma_percentile1.0  \
# 0                           1.049927                                0.044939
# 1                           1.162488                                0.027733
# 2                           0.950127                                0.060309
# 3                           0.982168                                0.096636
# 4                           1.285780                                0.019733
# ..                               ...                                     ...
# 530                         1.136842                                0.041037
# 531                         0.823229                                0.070675
# 532                         0.431707                                0.065914
# 533                         0.694604                                0.038487
# 534                         0.696137                                0.038573
#
#      ...  mfcc_sma_de[14]_peakRangeRel  mfcc_sma_de[14]_peakMeanAbs  \
# 0    ...                      0.650526                     2.615509
# 1    ...                      0.473101                     3.754133
# 2    ...                      0.599209                     2.833678
# 3    ...                      0.404925                     4.336186
# 4    ...                      0.431262                     4.122251
# ..   ...                           ...                          ...
# 530  ...                      0.583502                     3.618365
# 531  ...                      0.591960                     3.563173
# 532  ...                      0.514158                     2.859990
# 533  ...                      0.547805                     2.521827
# 534  ...                      0.446083                     4.191477
#
#      mfcc_sma_de[14]_peakMeanMeanDist  mfcc_sma_de[14]_peakMeanRel  \
# 0                            2.625846                   -19.942490
# 1                            3.718425                    19.426090
# 2                            2.874017                   -18.775923
# 3                            4.356391                   -19.904116
# 4                            4.145411                   -19.836735
# ..                                ...                          ...
# 530                          3.590731                    19.646263
# 531                          3.551121                    19.965895
# 532                          2.894242                   -19.097832
# 533                          2.543597                   -19.533463
# 534                          4.251155                   -18.775623
#
#      mfcc_sma_de[14]_minRangeRel  mfcc_sma_de[14]_meanRisingSlope  \
# 0                       0.477531                       111.844788
# 1                       0.542160                       156.864166
# 2                       0.418979                       132.770493
# 3                       0.476416                       136.753403
# 4                       0.617445                       173.396301
# ..                           ...                              ...
# 530                     0.496380                       133.139267
# 531                     0.357449                       152.175919
# 532                     0.525375                       117.317535
# 533                     0.563452                       111.379272
# 534                     0.586339                       167.816208
#
#      mfcc_sma_de[14]_stddevRisingSlope  mfcc_sma_de[14]_meanFallingSlope  \
# 0                            46.869637                         95.597328
# 1                            79.057297                        160.025116
# 2                            52.613449                        127.403091
# 3                            77.523903                        136.513428
# 4                            89.209602                        159.526917
# ..                                 ...                               ...
# 530                          65.644096                        136.440109
# 531                          84.059776                        155.173737
# 532                          58.800110                        114.213303
# 533                          48.147003                        104.253807
# 534                          55.807316                        176.364700
#
#      mfcc_sma_de[14]_stddevFallingSlope         filename
# 0                             44.616516  wav/16a02Lb.wav
# 1                             90.678070  wav/14a07Wc.wav
# 2                             57.301182  wav/10a07Ad.wav
# 3                             64.785980  wav/13a05Ea.wav
# 4                             81.902145  wav/14a05Wa.wav
# ..                                  ...              ...
# 530                           73.801018  wav/08b01Fd.wav
# 531                           81.292374  wav/03b02Aa.wav
# 532                           57.544956  wav/09a05Lc.wav
# 533                           45.597149  wav/08a05Lc.wav
# 534                           70.096436  wav/14a05Aa.wav
#
# [535 rows x 6374 columns]

# %%
Data
# Out:
#             filename    label
# 0    wav/16a02Lb.wav  Boredom
# 1    wav/14a07Wc.wav    Angry
# 2    wav/10a07Ad.wav     Fear
# 3    wav/13a05Ea.wav  Disgust
# 4    wav/14a05Wa.wav    Angry
# ..               ...      ...
# 530  wav/08b01Fd.wav    Happy
# 531  wav/03b02Aa.wav     Fear
# 532  wav/09a05Lc.wav  Boredom
# 533  wav/08a05Lc.wav  Boredom
# 534  wav/14a05Aa.wav     Fear
#
# [535 rows x 2 columns]

# %%
processed_df = pd.merge(Data, features_df, on='filename', how='inner')
processed_df
# Out:
#             filename    label  audspec_lengthL1norm_sma_range  \
# 0    wav/16a02Lb.wav  Boredom                        3.552382
# 1    wav/14a07Wc.wav    Angry                        3.742779
# 2    wav/10a07Ad.wav     Fear                        2.909269
# 3    wav/13a05Ea.wav  Disgust                        2.482837
# 4    wav/14a05Wa.wav    Angry                        3.798883
# ..               ...      ...                             ...
# 530  wav/08b01Fd.wav    Happy                        3.362022
# 531  wav/03b02Aa.wav     Fear                        3.407733
# 532  wav/09a05Lc.wav  Boredom                        3.657910
# 533  wav/08a05Lc.wav  Boredom                        2.882161
# 534  wav/14a05Aa.wav     Fear                        2.880234
#
#      audspec_lengthL1norm_sma_maxPos  audspec_lengthL1norm_sma_minPos  \
# 0                           0.313433                         0.019900
# 1                           0.793970                         0.000000
# 2                           0.352941                         0.973856
# 3                           0.082524                         0.961165
# 4                           0.572519                         0.020356
# ..                               ...                              ...
# 530                         0.224066                         0.970954
# 531                         0.455150                         0.000000
# 532                         0.124620                         0.009119
# 533                         0.126521                         0.961071
# 534                         0.585657                         0.011952
#
#      audspec_lengthL1norm_sma_quartile1  audspec_lengthL1norm_sma_quartile2  \
# 0                              0.416416                            0.864809
# 1                              0.310724                            0.652575
# 2                              0.571077                            1.109974
# 3                              0.665067                            1.097788
# 4                              0.357622                            0.830027
# ..                                  ...                                 ...
# 530                            0.534979                            1.055917
# 531                            0.775938                            1.113877
# 532                            0.492631                            0.691403
# 533                            0.443412                            0.725012
# 534                            0.560481                            0.923816
#
#      audspec_lengthL1norm_sma_quartile3  audspec_lengthL1norm_sma_iqr1-2  \
# 0                              1.466342                         0.448394
# 1                              1.473212                         0.341851
# 2                              1.521203                         0.538897
# 3                              1.647235                         0.432721
# 4                              1.643402                         0.472405
# ..                                  ...                              ...
# 530                            1.671821                         0.520938
# 531                            1.599168                         0.337938
# 532                            0.924337                         0.198772
# 533                            1.138016                         0.281601
# 534                            1.256618                         0.363336
#
#      audspec_lengthL1norm_sma_iqr2-3  ...  mfcc_sma_de[14]_peakRangeAbs  \
# 0                           0.601533  ...                      7.444389
# 1                           0.820637  ...                      8.095151
# 2                           0.411230  ...                      6.815187
# 3                           0.549446  ...                      7.149992
# 4                           0.813375  ...                     10.044664
# ..                               ...  ...                           ...
# 530                         0.615904  ...                      9.396194
# 531                         0.485291  ...                     11.604774
# 532                         0.232935  ...                      6.879107
# 533                         0.413004  ...                      8.315532
# 534                         0.332802  ...                      8.102887
#
#      mfcc_sma_de[14]_peakRangeRel  mfcc_sma_de[14]_peakMeanAbs  \
# 0                        0.650526                     2.615509
# 1                        0.473101                     3.754133
# 2                        0.599209                     2.833678
# 3                        0.404925                     4.336186
# 4                        0.431262                     4.122251
# ..                            ...                          ...
# 530                      0.583502                     3.618365
# 531                      0.591960                     3.563173
# 532                      0.514158                     2.859990
# 533                      0.547805                     2.521827
# 534                      0.446083                     4.191477
#
#      mfcc_sma_de[14]_peakMeanMeanDist  mfcc_sma_de[14]_peakMeanRel  \
# 0                            2.625846                   -19.942490
# 1                            3.718425                    19.426090
# 2                            2.874017                   -18.775923
# 3                            4.356391                   -19.904116
# 4                            4.145411                   -19.836735
# ..                                ...                          ...
# 530                          3.590731                    19.646263
# 531                          3.551121                    19.965895
# 532                          2.894242                   -19.097832
# 533                          2.543597                   -19.533463
# 534                          4.251155                   -18.775623
#
#      mfcc_sma_de[14]_minRangeRel  mfcc_sma_de[14]_meanRisingSlope  \
# 0                       0.477531                       111.844788
# 1                       0.542160                       156.864166
# 2                       0.418979                       132.770493
# 3                       0.476416                       136.753403
# 4                       0.617445                       173.396301
# ..                           ...                              ...
# 530                     0.496380                       133.139267
# 531                     0.357449                       152.175919
# 532                     0.525375                       117.317535
# 533                     0.563452                       111.379272
# 534                     0.586339                       167.816208
#
#      mfcc_sma_de[14]_stddevRisingSlope  mfcc_sma_de[14]_meanFallingSlope  \
# 0                            46.869637                         95.597328
# 1                            79.057297                        160.025116
# 2                            52.613449                        127.403091
# 3                            77.523903                        136.513428
# 4                            89.209602                        159.526917
# ..                                 ...                               ...
# 530                          65.644096                        136.440109
# 531                          84.059776                        155.173737
# 532                          58.800110                        114.213303
# 533                          48.147003                        104.253807
# 534                          55.807316                        176.364700
#
#      mfcc_sma_de[14]_stddevFallingSlope
# 0                             44.616516
# 1                             90.678070
# 2                             57.301182
# 3                             64.785980
# 4                             81.902145
# ..                                  ...
# 530                           73.801018
# 531                           81.292374
# 532                           57.544956
# 533                           45.597149
# 534                           70.096436
#
# [535 rows x 6375 columns]

# %% [markdown]
# Deep Learning

# %%
import torch
from torch import nn
import os
os.environ["TORCH_METAL_ENABLED"] = "1"

class MLP(nn.Module):

    def __init__(self, no_features, no_hidden, no_labels):
        super().__init__()
        layers = []
        parameters = [no_features] + no_hidden
        for i in range(len(parameters) - 1):
            layers.append(nn.Linear(parameters[i], parameters[i+1]))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(0.2))
        
        self.mlp_stack = nn.Sequential(*layers)
        self.fc = nn.Linear(parameters[-1], no_labels)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x1 = self.mlp_stack(x)
        u = self.fc(x1)
        y = self.softmax(u)
        return y
    
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

# %%
import tqdm
import time
import random 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from scipy.io import wavfile as wav

from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix



def split_dataset(df, columns_to_drop, test_size, random_state):
    label_encoder = preprocessing.LabelEncoder()

    df['label'] = label_encoder.fit_transform(df['label'])

    df_train, df_test = train_test_split(df, test_size=test_size, random_state=random_state)

    df_train2 = df_train.drop(columns_to_drop,axis=1)
    y_train2 = df_train['label'].to_numpy()

    df_test2 = df_test.drop(columns_to_drop,axis=1)
    y_test2 = df_test['label'].to_numpy() 

    return df_train2, y_train2, df_test2, y_test2

def preprocess_dataset(df_train, df_test):

    standard_scaler = preprocessing.StandardScaler()
    df_train_scaled = standard_scaler.fit_transform(df_train)

    df_test_scaled = standard_scaler.transform(df_test)

    return df_train_scaled, df_test_scaled

# %%
def preprocess(df):
    columns_to_drop = ['filename', 'label']
    test_size = 0.25
    random_state = 1
    X_train, y_train, X_test, y_test = split_dataset(df, columns_to_drop, test_size, random_state)
    X_train_scaled, X_test_scaled = preprocess_dataset(X_train, X_test)
    
    return X_train_scaled, y_train, X_test_scaled, y_test

X_train_scaled, y_train, X_test_scaled, y_test = preprocess(processed_df)

# %%
class CustomDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

def intialise_loaders(X_train_scaled, y_train, X_test_scaled, y_test, batch_size):
    train_data = CustomDataset(X_train_scaled, y_train)
    test_data = CustomDataset(X_test_scaled, y_test)
    train_dataloader = DataLoader(train_data, batch_size, shuffle=True)
    test_dataloader = DataLoader(test_data, batch_size, shuffle=True)
    return train_dataloader, test_dataloader

optimal_bs = 256
train_dataloader, test_dataloader = intialise_loaders(X_train_scaled, y_train, X_test_scaled, y_test, optimal_bs)

# %%
no_features = X_train_scaled.shape[1]
no_hidden = [128]
no_labels = 7
model = MLP(no_features, no_hidden, no_labels)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()

# %%
# early stopping obtained from tutorial
class EarlyStopper:
    def __init__(self, patience=3, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = np.inf

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
num_epochs = 1000
batch_size = 64
early_stopper = EarlyStopper(patience=5, min_delta=0.005)

training_losses = []
training_accuracy = []
validation_losses = []
validation_accuracy = []

for epoch in range(num_epochs):
    model.train()    
    training_loss = 0
    training_correct_preds = 0
    total = 0
    
    # training
    for inputs, labels in train_dataloader:
        # forward pass
        outputs = model(inputs)
        loss = loss_fn(outputs, labels)

        # backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # track loss and accuracy
        training_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        training_correct_preds += (predicted == labels).sum().item()
        
    training_losses.append(training_loss / len(train_dataloader))
    training_accuracy.append(training_correct_preds / len(train_dataloader.dataset))
        
    # validation
    model.eval() 
    with torch.no_grad():
        validation_loss = 0
        validation_correct_preds = 0
        for inputs, labels in test_dataloader:
            outputs = model(inputs)
            loss = loss_fn(outputs, labels)
            validation_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            validation_correct_preds += (predicted == labels).sum().item()
    
    validation_losses.append(validation_loss / len(test_dataloader))
    validation_accuracy.append(validation_correct_preds / len(test_dataloader.dataset))
    
    # early stopping
    if early_stopper.early_stop(validation_loss):
        print(f"Stopped early at epoch {epoch}.")
        print(f"Training Loss: {training_losses[-1]}, Validation Loss: {validation_losses[-1]}, Training Accuracy: {training_accuracy[-1]}, Validation Accuracy: {validation_accuracy[-1]}")
        break

    print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {training_losses[-1]}, Validation Loss: {validation_losses[-1]}, Training Accuracy: {training_accuracy[-1]}, Validation Accuracy: {validation_accuracy[-1]}")
# Out:
# Epoch [1/1000], Training Loss: 1.8340869545936584, Validation Loss: 1.602933406829834, Training Accuracy: 0.2942643391521197, Validation Accuracy: 0.5671641791044776
# Epoch [40/1000], Training Loss: 1.1707180738449097, Validation Loss: 1.299250602722168, Training Accuracy: 0.9950124688279302, Validation Accuracy: 0.8731343283582089
# Stopped early at epoch 40.
# Training Loss: 1.1708247065544128, Validation Loss: 1.2992864847183228, Training Accuracy: 0.9950124688279302, Validation Accuracy: 0.8731343283582089

# %%
import matplotlib.pyplot as plt

# plot accuracies
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(range(len(training_accuracy)), training_accuracy, label='Training Accuracy')
plt.plot(range(len(validation_accuracy)), validation_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracies')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# plot losses
plt.subplot(1, 2, 2)
plt.plot(range(len(training_losses)), training_losses, label='Training Loss')
plt.plot(range(len(validation_losses)), validation_losses, label='Validation Loss')
plt.title('Training and Validation Losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
def generate_cv_folds_for_parameters(parameters, X_train, y_train):
    """
    returns:
    X_train_scaled_dict(dict) where X_train_scaled_dict[parameter] is a list of the preprocessed training matrix for the different folds.
    X_val_scaled_dict(dict) where X_val_scaled_dict[parameter] is a list of the processed validation matrix for the different folds.
    y_train_dict(dict) where y_train_dict[parameter] is a list of labels for the different folds
    y_val_dict(dict) where y_val_dict[parameter] is a list of labels for the different folds
    """
    standard_scaler = preprocessing.StandardScaler()
    X_train_scaled_dict = {}
    X_val_scaled_dict = {}
    y_train_dict = {}
    y_val_dict = {}

    for parameter in parameters:
        kfold = KFold(n_splits=5, shuffle=True, random_state=1)
        X_train_scaled_folds = []
        X_val_scaled_folds = []
        y_train_folds = []
        y_val_folds = []

        for train_index, val_index in kfold.split(X_train, y_train):
            X_train_fold = X_train[train_index]
            X_val_fold = X_train[val_index]
            y_train_fold = y_train[train_index]
            y_val_fold = y_train[val_index]

            X_train_scaled_fold = standard_scaler.fit_transform(X_train_fold)
            X_val_scaled_fold = standard_scaler.transform(X_val_fold)

            X_train_scaled_folds.append(X_train_scaled_fold)
            X_val_scaled_folds.append(X_val_scaled_fold)
            y_train_folds.append(y_train_fold)
            y_val_folds.append(y_val_fold)

        X_train_scaled_dict[parameter] = X_train_scaled_folds
        X_val_scaled_dict[parameter] = X_val_scaled_folds
        y_train_dict[parameter] = y_train_folds
        y_val_dict[parameter] = y_val_folds

    return X_train_scaled_dict, X_val_scaled_dict, y_train_dict, y_val_dict


batch_sizes = [32, 64, 128, 256, 512]

columns_to_drop = ['filename', 'label']

df_train2 = processed_df.drop(columns_to_drop,axis=1)
y_train2 = processed_df['label'].to_numpy()

X_train_scaled_dict, X_val_scaled_dict, y_train_dict, y_val_dict = generate_cv_folds_for_parameters(batch_sizes, df_train2.to_numpy(), y_train2)

# %%
from time import perf_counter

def intialise_loaders(X_train_scaled, y_train, X_test_scaled, y_test, batch_size):
    train_data = CustomDataset(X_train_scaled, y_train)
    test_data = CustomDataset(X_test_scaled, y_test)
    train_dataloader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    test_dataloader = DataLoader(test_data, batch_size=batch_size, shuffle=True)
    return train_dataloader, test_dataloader

def find_optimal_hyperparameter(X_train_scaled_dict, X_val_scaled_dict, y_train_dict, y_val_dict, batch_sizes, string): # sting = 'batch_size'
    cross_validation_accuracies = {}
    cross_validation_times = {}
    
    num_epochs = 100
    
    # iterate through all batch_sizes
    for batch_size in batch_sizes:
        print(f"Batch size: {batch_size}")
        last_epoch_accuracies = []
        last_epoch_times = []
        
        # 5 fold cross validation
        for i in range(5):
            print(f"Fold: {i+1}")
            early_stopper = EarlyStopper(patience=5, min_delta=0.005)
            train_dataloader, test_dataloader = intialise_loaders(X_train_scaled_dict[batch_size][i], y_train_dict[batch_size][i], X_val_scaled_dict[batch_size][i], y_val_dict[batch_size][i], batch_size)

            # new model instance
            no_features = X_train_scaled_dict[batch_size][i].shape[1]
            no_hidden = [128]
            no_labels = 7
            model = MLP(no_features, no_hidden, no_labels)
            optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
            loss_fn = nn.CrossEntropyLoss()

            training_losses = []
            training_accuracy = []
            validation_losses = []
            validation_accuracy = []

            # train model
            for epoch in range(num_epochs):
                start = perf_counter() 
                model.train()    
                training_loss = 0
                training_correct_preds = 0

                for inputs, labels in train_dataloader:
                    # forward pass
                    outputs = model(inputs)
                    loss = loss_fn(outputs, labels)

                    # backward pass and optimization
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()
                    
                    # track loss and accuracy
                    training_loss += loss.item()
                    _, predicted = torch.max(outputs.data, 1)
                    training_correct_preds += (predicted == labels).sum().item()

                training_losses.append(training_loss / len(train_dataloader))
                training_accuracy.append(training_correct_preds / len(train_dataloader.dataset))

                # validation
                model.eval()
                with torch.no_grad():
                    validation_loss = 0
                    validation_correct_preds = 0
                    for inputs, labels in test_dataloader:
                        outputs = model(inputs)
                        loss = loss_fn(outputs, labels)
                        validation_loss += loss.item()
                        _, predicted = torch.max(outputs.data, 1)
                        validation_correct_preds += (predicted == labels).sum().item()

                validation_losses.append(validation_loss / len(test_dataloader))
                validation_accuracy.append(validation_correct_preds / len(test_dataloader.dataset))
                
                end = perf_counter() 

                # early stopping
                if early_stopper.early_stop(validation_loss):
                    print(f"Stopped early at epoch {epoch}.")
                    print(f"Training Loss: {training_losses[-1]}, Validation Loss: {validation_losses[-1]}, Training Accuracy: {training_accuracy[-1]}, Validation Accuracy: {validation_accuracy[-1]}")
                    break

            last_epoch_accuracies.append(validation_accuracy[-1])
            elapsed_time = end - start
            last_epoch_times.append(elapsed_time)
            print()
        print()
        cross_validation_accuracies[batch_size] = last_epoch_accuracies
        cross_validation_times[batch_size] = last_epoch_times
    return cross_validation_accuracies, cross_validation_times
    
cross_validation_accuracies, cross_validation_times = find_optimal_hyperparameter(X_train_scaled_dict, X_val_scaled_dict, y_train_dict, y_val_dict, batch_sizes, 'batch_size')
# Out:
# Batch size: 32
# Fold: 1
# Stopped early at epoch 8.
# Training Loss: 1.198815371309008, Validation Loss: 1.2832131087779999, Training Accuracy: 0.9672897196261683, Validation Accuracy: 0.8878504672897196
#
# Fold: 2
# Stopped early at epoch 18.
# Training Loss: 1.1932714070592607, Validation Loss: 1.311797857284546, Training Accuracy: 0.9742990654205608, Validation Accuracy: 0.8411214953271028
#
# Fold: 3
# Stopped early at epoch 18.
#
#
# Batch size: 512
# Fold: 1
# Stopped early at epoch 23.
# Training Loss: 1.179923415184021, Validation Loss: 1.2993922233581543, Training Accuracy: 0.9883177570093458, Validation Accuracy: 0.8598130841121495
#
# Fold: 2
# Stopped early at epoch 32.
# Training Loss: 1.1811628341674805, Validation Loss: 1.3400028944015503, Training Accuracy: 0.9836448598130841, Validation Accuracy: 0.822429906542056
#
# Fold: 3
#
# Fold: 4
# Stopped early at epoch 43.
# Training Loss: 1.1750316619873047, Validation Loss: 1.3142998218536377, Training Accuracy: 0.9906542056074766, Validation Accuracy: 0.8411214953271028
#
# Fold: 5

# %%
import matplotlib.pyplot as plt

mean_cross_validation_accuracies = []
for batch_size, cross_validation_accuracy in cross_validation_accuracies.items():
    mean_cross_validation_accuracies.append(sum(cross_validation_accuracy) / len(cross_validation_accuracy) * 100)
    
# plot accuracies
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(batch_sizes, mean_cross_validation_accuracies, label=f'Mean Accuracy')
plt.title('Validation Accuracies')
plt.xlabel('Batch Size')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
optimal_bs = 256

# %%
from time import perf_counter

def train(model, train_dataloader, test_dataloader):
    num_epochs = 10000
    early_stopper = EarlyStopper(patience=5, min_delta=0.005)
    # train_dataloader, test_dataloader = intialise_loaders(X_train_scaled[neurons_tuple], y_train2, X_val_scaled, y_val2, batch_size)
    # train_dataloader, test_dataloader = intialise_loaders(X_train_scaled_dict[batch_size][i], y_train_dict[batch_size][i], X_val_scaled_dict[batch_size][i], y_val_dict[batch_size][i], batch_size)


    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    loss_fn = nn.CrossEntropyLoss()

    train_accuracies = []
    train_losses = []
    test_accuracies = []
    test_losses = []
    times = []


    # train model
    for epoch in range(num_epochs):
        start = perf_counter() 
        model.train()    
        training_loss = 0
        training_correct_preds = 0

        for inputs, labels in train_dataloader:
            # forward pass
            outputs = model(inputs.to(device))
            loss = loss_fn(outputs, labels.to(device))

            # backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            # track loss and accuracy
            training_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            training_correct_preds += (predicted.to(torch.device("cpu")) == labels.to(torch.device("cpu"))).sum().item()

        train_losses.append(training_loss / len(train_dataloader))
        train_accuracies.append(training_correct_preds / len(train_dataloader.dataset))

        # validation
        model.eval()
        with torch.no_grad():
            validation_loss = 0
            validation_correct_preds = 0
            for inputs, labels in test_dataloader:
                outputs = model(inputs.to(device))
                loss = loss_fn(outputs, labels.to(device))
                validation_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                validation_correct_preds += (predicted.to(torch.device("cpu")) == labels.to(torch.device("cpu"))).sum().item()

        # validation_losses.append(validation_loss / len(test_dataloader))
        # validation_accuracy.append(validation_correct_preds / len(test_dataloader.dataset))

        test_losses.append(validation_loss / len(test_dataloader))
        test_accuracies.append(validation_correct_preds / len(test_dataloader.dataset))
        end = perf_counter() 
        
        times.append(end - start)

        # early stopping
        if early_stopper.early_stop(validation_loss):
            print(f"Stopped early at epoch {epoch}.")
            print(f"Training Loss: {train_losses[-1]}, Validation Loss: {test_losses[-1]}, Training Accuracy: {train_accuracies[-1]}, Validation Accuracy: {test_accuracies[-1]}")
            break

    return train_accuracies, train_losses, test_accuracies, test_losses, times

# %%
answer = "test the model accuracy after training on different 1-layer combinations, then choose the most optimal width. Then, test if adding another layer improves the accuracy, and so on. If adding a layer does not improve accuracy, we can stop searching because the higher model complexity is detrimental to performance."

def find_optimal_hyperparameter2(X_train, y_train, parameters, mode, batch_size):
    
    no_hidden_final = []
    best_acc = 0
    
    # maximum 3 layers
    for layer in range(3):
        cross_validation_accuracies = {}
        cross_validation_times = {}
        
        # possible widths in each layer
        for new_layer in [64, 128, 256, 512]:
            neurons = no_hidden_final.copy()
            neurons.append(new_layer)
            neurons_tuple = tuple(neurons)
            
            X_train_scaled_dict, X_val_scaled_dict, y_train_dict, y_val_dict = generate_cv_folds_for_parameters([neurons_tuple], X_train, y_train)
            
            # 5 fold cross validation
            print(f"Neurons: {neurons}")
            last_epoch_accuracies = []
            last_epoch_times = []
            for i in range(5):
                print(f"Fold: {i+1}")
                train_dataloader, test_dataloader = intialise_loaders(X_train_scaled_dict[neurons_tuple][i], y_train_dict[neurons_tuple][i], X_val_scaled_dict[neurons_tuple][i], y_val_dict[neurons_tuple][i], batch_size)

                # X_train_scaled = X_train_scaled_dict[neurons_tuple][i]
                # y_train2 = y_train_dict[neurons_tuple][i]
                # X_val_scaled = X_val_scaled_dict[neurons_tuple][i]
                # y_val2 = y_val_dict[neurons_tuple][i]

                # initialise model with neuron combination to be tested
                no_features = X_train_scaled_dict[neurons_tuple][i].shape[1]
                no_hidden = list(neurons_tuple)
                no_labels = 7
                model = MLP(no_features, no_hidden, no_labels).to(device)

                # train model
                train_accuracies, train_losses, test_accuracies, test_losses, times = train(model, train_dataloader, test_dataloader)

                last_epoch_accuracies.append(test_accuracies[-1])
                last_epoch_times.append(times[-1])

            cross_validation_accuracies[neurons_tuple] = last_epoch_accuracies
            print(last_epoch_accuracies)
            cross_validation_times[neurons_tuple] = last_epoch_times
        
        
        # check if accuracy is improving. if not, break the loop
        for neurons, accuracies in cross_validation_accuracies.items():
            if (sum(accuracies) / len(accuracies)) > best_acc:
                no_hidden_final = list(neurons)
                best_acc = sum(accuracies) / len(accuracies)
        if len(no_hidden_final) == layer:
            break
    return no_hidden_final

# df = pd.read_csv('simplified.csv')

label_encoder = preprocessing.LabelEncoder()

y_train = processed_df['label']
y_train = label_encoder.fit_transform(y_train)
X_train = processed_df.drop(['filename', 'label'],axis=1)

optimal_bs = 256


# import itertools

# Define the list of values
# neuron_values = [512, 1024, 2048]

# Generate all combinations up to 3 items each in any order
# num_neurons_lists = []
# for r in range(3, 6):
#     combinations = itertools.product(neuron_values, repeat=r)
#     num_neurons_lists.extend([list(combination) for combination in combinations])

# print(num_neurons_lists)


# num_neurons_lists = [[64], [128], [256], [64, 64], [128, 128], [256, 256], [64, 128], [128, 64], [128, 256], [64, 256], [256, 128], [256, 64], [64, 64, 64], [128, 128, 128], [256, 256, 256], [64, 128, 256], [64, 256, 256], [128, 64, 64], [128, 128, 64], [256, 128, 64], [256, 256, 128]]
# Fold: 4
# Stopped early at epoch 35.
# Training Loss: 1.1698794960975647, Validation Loss: 1.3273011445999146, Training Accuracy: 0.9976635514018691, Validation Accuracy: 0.8317757009345794
# Fold: 5
# Stopped early at epoch 17.
# Training Loss: 1.2115563750267029, Validation Loss: 1.3874315023422241, Training Accuracy: 0.9626168224299065, Validation Accuracy: 0.7663551401869159
# [0.8598130841121495, 0.822429906542056, 0.794392523364486, 0.8317757009345794, 0.7663551401869159]
# Neurons: [64, 256]
# Fold: 1
# Stopped early at epoch 29.
# Training Loss: 1.1691604852676392, Validation Loss: 1.300005316734314, Training Accuracy: 1.0, Validation Accuracy: 0.8691588785046729
# Fold: 2
# Stopped early at epoch 35.
# Training Loss: 1.1772194504737854, Validation Loss: 1.3337576389312744, Training Accuracy: 0.9906542056074766, Validation Accuracy: 0.822429906542056
# Fold: 3
# Stopped early at epoch 31.
# Training Loss: 1.1783764362335205, Validation Loss: 1.3906497955322266, Training Accuracy: 0.9883177570093458, Validation Accuracy: 0.7757009345794392
# Fold: 4
# Stopped early at epoch 28.
# Training Loss: 1.1770280599594116, Validation Loss: 1.3209445476531982, Training Accuracy: 0.9906542056074766, Validation Accuracy: 0.8411214953271028
# Fold: 5
# Stopped early at epoch 16.
# Training Loss: 1.1943727731704712, Validation Loss: 1.3505445718765259, Training Accuracy: 0.9742990654205608, Validation Accuracy: 0.8130841121495327
# [0.8691588785046729, 0.822429906542056, 0.7757009345794392, 0.8411214953271028, 0.8130841121495327]
# Neurons: [64, 512]
# Fold: 1
# Stopped early at epoch 21.
# Training Loss: 1.192198932170868, Validation Loss: 1.2803276777267456, Training Accuracy: 0.9742990654205608, Validation Accuracy: 0.8785046728971962
# Fold: 2
# Stopped early at epoch 14.
# Training Loss: 1.2107751369476318, Validation Loss: 1.365738034248352, Training Accuracy: 0.9626168224299065, Validation Accuracy: 0.7850467289719626
# Fold: 3
# Stopped early at epoch 50.
# Training Loss: 1.1723496317863464, Validation Loss: 1.359355092048645, Training Accuracy: 0.9929906542056075, Validation Accuracy: 0.8130841121495327
# Fold: 4
# Stopped early at epoch 28.
# Training Loss: 1.1692063212394714, Validation Loss: 1.3389050960540771, Training Accuracy: 0.9976635514018691, Validation Accuracy: 0.8317757009345794
# Fold: 5
# Stopped early at epoch 26.
# Training Loss: 1.1776703596115112, Validation Loss: 1.3625850677490234, Training Accuracy: 0.9906542056074766, Validation Accuracy: 0.7850467289719626
# [0.8785046728971962, 0.7850467289719626, 0.8130841121495327, 0.8317757009345794, 0.7850467289719626]
#
# optimal combination: [64]

# %%
model = MLP(no_features, no_hidden_final, no_labels)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()

# %%
num_epochs = 1000
batch_size = 64
early_stopper = EarlyStopper(patience=5, min_delta=0.005)

training_losses = []
training_accuracy = []
validation_losses = []
validation_accuracy = []

for epoch in range(num_epochs):
    model.train()    
    training_loss = 0
    training_correct_preds = 0
    total = 0
    
    # training
    for inputs, labels in train_dataloader:
        # forward pass
        outputs = model(inputs)
        loss = loss_fn(outputs, labels)

        # backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # track loss and accuracy
        training_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        training_correct_preds += (predicted == labels).sum().item()
        
    training_losses.append(training_loss / len(train_dataloader))
    training_accuracy.append(training_correct_preds / len(train_dataloader.dataset))
        
    # validation
    model.eval() 
    with torch.no_grad():
        validation_loss = 0
        validation_correct_preds = 0
        for inputs, labels in test_dataloader:
            outputs = model(inputs)
            loss = loss_fn(outputs, labels)
            validation_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            validation_correct_preds += (predicted == labels).sum().item()
    
    validation_losses.append(validation_loss / len(test_dataloader))
    validation_accuracy.append(validation_correct_preds / len(test_dataloader.dataset))
    
    # early stopping
    if early_stopper.early_stop(validation_loss):
        print(f"Stopped early at epoch {epoch}.")
        print(f"Training Loss: {training_losses[-1]}, Validation Loss: {validation_losses[-1]}, Training Accuracy: {training_accuracy[-1]}, Validation Accuracy: {validation_accuracy[-1]}")
        break

    print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {training_losses[-1]}, Validation Loss: {validation_losses[-1]}, Training Accuracy: {training_accuracy[-1]}, Validation Accuracy: {validation_accuracy[-1]}")
# Out:
# Epoch [1/1000], Training Loss: 1.85154527425766, Validation Loss: 1.6426589488983154, Training Accuracy: 0.2344139650872818, Validation Accuracy: 0.6044776119402985
# Epoch [2/1000], Training Loss: 1.5645413398742676, Validation Loss: 1.4970263242721558, Training Accuracy: 0.6608478802992519, Validation Accuracy: 0.6940298507462687
# Epoch [3/1000], Training Loss: 1.4184423089027405, Validation Loss: 1.4334958791732788, Training Accuracy: 0.7980049875311721, Validation Accuracy: 0.7761194029850746
# Epoch [4/1000], Training Loss: 1.3527103662490845, Validation Loss: 1.3814555406570435, Training Accuracy: 0.8329177057356608, Validation Accuracy: 0.8059701492537313
# Epoch [5/1000], Training Loss: 1.291728675365448, Validation Loss: 1.354939579963684, Training Accuracy: 0.9052369077306733, Validation Accuracy: 0.8507462686567164
# Epoch [6/1000], Training Loss: 1.2528736591339111, Validation Loss: 1.3442440032958984, Training Accuracy: 0.9276807980049875, Validation Accuracy: 0.835820895522388
# Epoch [7/1000], Training Loss: 1.242430865764618, Validation Loss: 1.3374090194702148, Training Accuracy: 0.9451371571072319, Validation Accuracy: 0.8582089552238806
# Epoch [8/1000], Training Loss: 1.2197315692901611, Validation Loss: 1.3303536176681519, Training Accuracy: 0.9576059850374065, Validation Accuracy: 0.8507462686567164
# Epoch [9/1000], Training Loss: 1.2171271443367004, Validation Loss: 1.3250938653945923, Training Accuracy: 0.9600997506234414, Validation Accuracy: 0.8656716417910447
# Epoch [10/1000], Training Loss: 1.2037813663482666, Validation Loss: 1.3204600811004639, Training Accuracy: 0.9675810473815462, Validation Accuracy: 0.8582089552238806
# Epoch [11/1000], Training Loss: 1.1992636919021606, Validation Loss: 1.3138655424118042, Training Accuracy: 0.9675810473815462, Validation Accuracy: 0.8731343283582089
# Epoch [12/1000], Training Loss: 1.1890522837638855, Validation Loss: 1.3076051473617554, Training Accuracy: 0.9800498753117207, Validation Accuracy: 0.8805970149253731
